# %% [markdown]
# # Daniel Rodríguez Guillén
#
# Curso: Mecánica Analítica
#
# Tarea 2
#
# Fecha de Entrega: 18-10-2018

# %% [markdown]
# ## El péndulo forzado amorgituado
#
# la ecuación del péndulo forzado amortiguado es
#
# Aceleración+Amortiguamiento+Gravedad=Fuerza externa
#
# Que como ecuación se ve
#
# $$\ddot{\theta}+\mu \dot{\theta}+\sin(\theta)=A \cos (w_d \ t)$$
#
# 1.- Límite lineal. Considerando ángulos pequeños, tenemos la ecuación lineal forzada y amortiguada vista en clase, cuya solución particular (aquella que domina a tiempos grandes) tiene una función Coseno con una cierta amplitud y fase dada en términos de los parametros de la ecuación anterior. Tomando $A=1, \omega_0=1, \mu=0.05$

# %% [markdown]
# **a) Graficar la Amplitud como función de la frecuencia de la fuerza externa. ¿Exista alguna resonancia?**

# %% [markdown]
# <font color=blue>
#
# Tenemos que la solución a la ecuación diferencial es: $$\boxed{\theta(t) = \theta_{hom} + \frac{A}{\sqrt{(\omega_o^2-
# \omega^2)^2+\mu^2\omega^2}}\cos(\omega t - \delta)}$$
#
# Donde $$\boxed{\delta = \tan^{-1}\left(\frac{\mu\omega}{\omega_0^2 - \omega^2}\right)} $$
#
#
# Tomamos solamente la amplitud que está en función de la frecuencia externa $\omega$ y los valores A = 1, $\omega_0 = 1$, $\mu = 0.05 $
#
#
# </font>

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt

w = np.linspace(0,5,1000)                                 #Valores para la frecuencia externa w, desde 0 hasta 5
mu = 0.05

def A(w):                                                #Definimos la funcion para la amplitud
    return 1/(np.sqrt((1 - w**2)**2 + (w**2)*(mu**2))) 


plt.figure(figsize = (9,6))
plt.title("Amplitud como función de la frecuencia externa", color = "red", fontsize = 20)
plt.ylabel("Amplitud",fontsize = 18)
plt.ylim(0,22.5)
plt.xlabel("Frecuencia", fontsize = 18)
plt.xlim(0,3.5)
plt.grid(True)
plt.plot(w,A(w), color = "orange")
plt.show()

# %% [markdown]
# <font color=blue>
# Para determinar si existe resonancia, buscamos el valor de $\omega$ en el cual la amplitud es máxima , esto es $$\frac{dD}{d\omega} = 0$$
# La derivada de la amplitud respecto a la función debe ser igual a cero en algun valor de $\omega$.
#
# La resonancia se produce cuando la frecuencia externa es igual a la frecuencia natural del sistema. En conclusión si existe resonancia y es en $\omega= 1$.
# <br>
# Si $\mu < \omega_0$ Existe resonancia.
# </font>

# %% [markdown]
# **b) Graficar la Fase de la solución como función de la frecuencia de la fuerza externa.**

# %% [markdown]
# <font color=blue>
#
# Tenemos que la fase de la solución es:
# $$\boxed{\delta = \tan^{-1}\left(\frac{\mu\omega}{\omega_0^2 - \omega^2}\right)} $$
#
# Usando los mismos parametros:
# $\omega_0 = 1$, $\mu = 0.05 $
#
# </font>

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt

w = np.linspace(0,10,10000)                                 #Valores para la frecuencia externa w, desde 0 hasta 5
mu = 0.05
w[1000] = np.nan


def d(w):                                                #Definimos la funcion para la amplitud
    return np.arctan((mu*w)/(1-w**2))


plt.figure(figsize = (14,6))
plt.title("Fase como función de la frecuencia externa", color = "red", fontsize = 20)
plt.ylabel("Fase",fontsize = 18)
plt.ylim(-1.7,1.7)
plt.xlabel("Frecuencia", fontsize = 18)
plt.xlim(0,2)
plt.grid(True)
plt.plot(w,d(w), color = "orange")
plt.show()

# %% [markdown]
# **c) Graficar el ángulo y la velocidad angular como función del tiempo para 2 condiciones iniciales distintas.**

# %% [markdown]
# <font color=blue>
# De la solución homogenea se encuentran tres casos: Infra-amortiguado, amortiguamiento crítico y sobreamortiguado, dado que $\omega_0^2 > \frac{\mu^2}{4}$ nos encontramos en el caso infra-amortiguado. Para este caso la solución viene expresa de la siguiente manera:
# <br>
#
#     $$ \boxed{\theta(t) = Ae^{(-\frac{\mu}{2}t)}cos\left(\sqrt{\omega_0^2 - \frac{\mu^2}{4}}t - \epsilon \right)}$$
#
# Tomamos de nuevo $\omega_0 = 1$, A = 1, $\mu = 0.05$, Y $\epsilon = 0$ Por simplicidad y no tener un desfase.<br>
# <br>
# Debemos agregar la solución particular anteriormente vista, de tal manera que nuestra ecuación general queda de la siguiente forma:<br>
# <br>
# $$ \boxed{\theta(t) = Ae^{(-\frac{\mu}{2}t)}cos\left(\sqrt{\omega_0^2 - \frac{\mu^2}{4}}t - \epsilon \right) + \frac{A}{\sqrt{(\omega_o^2- \omega^2)^2+\mu^2\omega^2)}}\cos\left(\omega t - \tan^{-1}\left(\frac{\mu\omega}{\omega_0^2 - \omega^2}\right)\right)} $$
#
# <br>
# Y la velocidad angular:
#
# $$\boxed{\dot{\theta}(t) =-Ae^{-\frac{\mu}{2}t}\left[\frac{\mu}{2}\cdot \cos\left(\sqrt{\omega_0^2 - \frac{\mu^2}{4}}t\right) + \sqrt{\omega_0^2 - \frac{\mu^2}{4}}\cdot\sin\left(\sqrt{\omega_0^2 - \frac{\mu^2}{4}}t\right)\right] + \frac{A\omega}{\sqrt{(\omega_0^2- \omega^2)^2+\mu^2\omega^2)}}\sin\left(\omega t - \delta \right)}  $$
#
# <br>
# Tomaremos dos condiciones iniciales la primera $\omega=0.75$ y la segunda $\omega=0.1$
# </font>

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt

t = np.linspace(0,150,10000)                                 #Valores para el tiempo, desde 0 hasta 10
mu = 0.05
w = 0.35

def gen(t):                                                #Definimos la funcion para el angulo
    return np.exp((-mu/2)*t)*(np.cos(np.sqrt(1 - (mu/4)**2)*t)) + (1/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((mu*w)/(1-w**2)))) 

def hom(t):
    return np.exp((-mu/2)*t)*(np.cos(np.sqrt(1 - (mu/4)**2)*t))

def part(t):
    return (1/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((mu*w)/(1-w**2))))


plt.figure(figsize = (14,8))
plt.suptitle("Ángulos como función del tiempo (1er condición inicial)", color = "red", fontsize = 20)

plt.subplot2grid((2,1),(0,0), rowspan=1, colspan=2)
plt.title("Solución homogena y solución particular de ángulo como función del tiempo", fontsize = 15)
plt.ylabel("Ángulo",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t,hom(t), color = "purple", label = "sol. hom. $\omega_0=1$")
plt.plot(t, part(t), color = "blue", label = "sol. part $\omega=0.35$")
plt.legend(loc = "upper right", shadow = True)
plt.show()

plt.figure(figsize = (14,8))
plt.subplot2grid((2,1),(1,0), rowspan=1, colspan=2)
plt.title("Solución general de ángulo como función del tiempo", fontsize = 15)
plt.ylabel("Ángulo",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t, gen(t), color = "violet",label = "sol. general")
plt.legend(loc = "upper right", shadow = True)
plt.show()

w=0.1

plt.figure(figsize = (14,8))
plt.suptitle("Ángulos como función del tiempo (2da condición inicial)", color = "red", fontsize = 20)

plt.subplot2grid((2,1),(0,0), rowspan=1, colspan=2)
plt.title("Solución homogena y solución particular de ángulo como función del tiempo", fontsize = 15)
plt.ylabel("Ángulo",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t,hom(t), color = "purple", label = "sol. hom. $\omega_0=1$")
plt.plot(t, part(t), color = "blue", label = "sol. part $\omega=0.$")
plt.legend(loc = "upper right", shadow = True)
plt.show()

plt.figure(figsize = (14,8))
plt.subplot2grid((2,1),(1,0), rowspan=1, colspan=2)
plt.title("Solución general de ángulo como función del tiempo", fontsize = 15)
plt.ylabel("Angulo",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t, gen(t), color = "violet", label = "sol. general")
plt.legend(loc = "upper right", shadow = True)
plt.show()

# %% [markdown]
# <font color=blue>
# Podemos notar en ambas gráficas que la solución homogenea decae conforme el tiempo avanza, sin embargo la solución particular no, se puede notar entonces que al inicio la solución general tiene un comportamiento diferente que al del resto de la gráfica, a tiempos grandes la solución general se vuelve idéntica a la solución particular.
# </font>

# %% [markdown]
# <font color=blue>
# Ahora las gráficas de la velocidad
# </font>

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt

t = np.linspace(0,150,10000)                                 #Valores para el tiempo, desde 0 hasta 150
mu = 0.05
w = 0.35

def gen(t):                                                #Definimos la funcion para la velocidad
    return -np.exp((-mu/2)*t)*((mu/2)*np.cos(np.sqrt(1-(mu**2/4))*t) + np.sqrt(1-(mu**2/4))*np.sin(np.sqrt(1-(mu**2/4))*t)) + (w/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.sin(w*t - np.arctan((mu*w)/(1-w**2))))

def hom(t):
    return -np.exp((-mu/2)*t)*((mu/2)*np.cos(np.sqrt(1-(mu**2/4))*t) + np.sqrt(1-(mu**2/4))*np.sin(np.sqrt(1-(mu**2/4))*t))

def part(t):
    return (w/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.sin(w*t - np.arctan((mu*w)/(1-w**2))))


plt.figure(figsize = (14,8))
plt.suptitle("Velocidades como función del tiempo (1er condición inicial)", color = "red", fontsize = 20)

plt.subplot2grid((2,1),(0,0), rowspan=1, colspan=2)
plt.title("Solución homogena y solución particular de la velocidad como función del tiempo", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t,hom(t), color = "red", label = "sol. hom. $\omega_0=1$")
plt.plot(t, part(t), color = "orange", label = "sol. part $\omega=0.35$")
plt.legend(loc = "upper right", shadow = True)
plt.show()

plt.figure(figsize = (14,8))
plt.subplot2grid((2,1),(1,0), rowspan=1, colspan=2)
plt.title("Solución general de velocidad como función del tiempo", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t, gen(t), color = "violet", label = "sol. general")
plt.legend()
plt.show()

w=0.1

plt.figure(figsize = (14,8))
plt.suptitle("Velocidades como función del tiempo (2da condición inicial)", color = "red", fontsize = 20)

plt.subplot2grid((2,1),(0,0), rowspan=1, colspan=2)
plt.title("Solución homogena y solucion particular de la velocidad como función del tiempo", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t,hom(t), color = "red", label = "sol. hom. $\omega_0=1$")
plt.plot(t, part(t), color = "orange", label = "sol. part $\omega=0.1$")
plt.legend(loc = "upper right", shadow = True)
plt.show()

plt.figure(figsize = (14,8))
plt.subplot2grid((2,1),(1,0), rowspan=1, colspan=2)
plt.title("Solución general de la velocidad como función del tiempo", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t, gen(t), color = "violet", label = "sol. general")
plt.legend(loc = "upper right", shadow = True)
plt.show()

# %% [markdown]
# <font color=blue>
# Ahora las gráficas de ángulo y velocidad juntas
# </font>

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt

t = np.linspace(0,150,10000)                                 #Valores para el tiempo, desde 0 hasta 150
mu = 0.05
w = 0.35

def gena(t):                                                #Definimos la funcion para el angulo
    return np.exp((-mu/2)*t)*(np.cos(np.sqrt(1 - (mu/4)**2)*t)) + (1/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((mu*w)/(1-w**2)))) 

def genv(t):                                                #Definimos la funcion para la velocidad
    return -np.exp((-mu/2)*t)*((mu/2)*np.cos(np.sqrt(1-(mu**2/4))*t) + np.sqrt(1-(mu**2/4))*np.sin(np.sqrt(1-(mu**2/4))*t)) + (w/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.sin(w*t - np.arctan((mu*w)/(1-w**2))))

plt.figure(figsize = (14,8))
plt.suptitle("Ángulo y velocidad como función del tiempo (1er condición inicial)", color = "red", fontsize = 20)

plt.subplot2grid((2,1),(0,0), rowspan=1, colspan=2)
plt.title("Solución general", fontsize = 15)
plt.ylabel("Ángulo y velocidad",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t,gena(t), color = "red", label = "sol. gen. angulo")
plt.plot(t, genv(t), color = "blue", label = "sol. gen velocidad")
plt.legend(loc = "upper right", shadow = True)
plt.show()


w=0.1

plt.figure(figsize = (14,8))
plt.suptitle("Angulo y velocidad como función del tiempo (2da condición inicial)", color = "red", fontsize = 20)

plt.subplot2grid((2,1),(0,0), rowspan=1, colspan=2)
plt.title("Solución general", fontsize = 15)
plt.ylabel("Ángulo y velocidad",fontsize = 18)
plt.xlabel("Tiempo", fontsize = 18)
plt.grid(True)
plt.plot(t,gena(t), color = "red", label = "sol. gen. angulo")
plt.plot(t, genv(t), color = "blue", label = "sol. gen. velocidad")
plt.legend(loc = "upper right", shadow = True)
plt.show()

# %% [markdown]
# **d) Graficar en el espacio fase las 2 trayectorias con condiciones iniciales distintas del inciso anterior.**

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt

t = np.linspace(0,150,10000)                                 #Valores para el tiempo, desde 0 hasta 150
mu = 0.05
w = 0.35

def gena(t):                                                #Definimos la funcion para el angulo
    return np.exp((-mu/2)*t)*(np.cos(np.sqrt(1 - (mu/4)**2)*t)) + (1/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((mu*w)/(1-w**2)))) 

def genv(t):                                                #Definimos la funcion para la velocidad
    return -np.exp((-mu/2)*t)*((mu/2)*np.cos(np.sqrt(1-(mu**2/4))*t) + np.sqrt(1-(mu**2/4))*np.sin(np.sqrt(1-(mu**2/4))*t)) + (w/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.sin(w*t - np.arctan((mu*w)/(1-w**2))))

plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
plt.title("Espacio Fase (1er condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Ángulo", fontsize = 18)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "green", label="$\omega$=0.35")
plt.legend(loc = "upper right", shadow = True)


w=0.1

plt.subplot(1,2,2)
plt.title("Espacio Fase (2da condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Ángulo", fontsize = 18)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "green", label="$\omega$ = 0.10")
plt.legend(loc = "upper right", shadow = True)
plt.show()

# %% [markdown]
# **e) Graficar en el espacio fase 2 trayectorias con dos A's distintas, con $\mu=0$  y la misma confición inicial.**

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt

t = np.linspace(0,80,10000)                                 #Valores para el tiempo, desde 0 hasta 50
mu = 0
w = 0.43
A=4.2

def gena(t):                                                #Definimos la funcion para el angulo
    return np.exp((-mu/2)*t)*(np.cos(np.sqrt(1 - (mu/4)**2)*t)) + (A/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((mu*w)/(1-w**2)))) 

def genv(t):                                                #Definimos la funcion para la velocidad
    return -np.exp((-mu/2)*t)*((mu/2)*np.cos(np.sqrt(1-(mu**2/4))*t) + np.sqrt(1-(mu**2/4))*np.sin(np.sqrt(1-(mu**2/4))*t)) + (A*w/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.sin(w*t - np.arctan((mu*w)/(1-w**2))))

plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
plt.title("Espacio Fase (1er condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Ángulo", fontsize = 18)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "red", label= "A=4.2 , $\omega$=0.43")
plt.legend(loc = "upper right", shadow = True)

A=0.7
plt.subplot(1,2,2)
plt.title("Espacio Fase (2da condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Ángulo", fontsize = 18)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "red", label = "A=0.7 , $\omega$=0.43")
plt.legend(loc = "upper right", shadow = True)
plt.show()

# %% [markdown]
# **f) Graficar en el espacio fase 2 trayectorias con $\mu=0,2.0,0.1$, para la misma amplitud (A=1) y la misma condición inicial.**

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt

t = np.linspace(0,40,10000)                                 #Valores para el tiempo, desde 0 hasta 150
mu = 0
w = 0.39
A=1

def gena(t):                                                #Definimos la funcion para el angulo
    return np.exp((-mu/2)*t)*(np.cos(np.sqrt(1 - (mu/4)**2)*t)) + (A/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((mu*w)/(1-w**2)))) 

def genv(t):                                                #Definimos la funcion para la velocidad
    return -np.exp((-mu/2)*t)*((mu/2)*np.cos(np.sqrt(1-(mu**2/4))*t) + np.sqrt(1-(mu**2/4))*np.sin(np.sqrt(1-(mu**2/4))*t)) + (A*w/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.sin(w*t - np.arctan((mu*w)/(1-w**2))))

plt.figure(1,figsize=(25,25))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)

plt.subplot(321)
plt.title("Espacio Fase (1er condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 25)
plt.xlabel("Ángulo", fontsize = 25)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "green", label = "$\mu$=0 , $\omega$=0.39")
plt.tick_params(labelsize=20)
plt.legend(loc = "upper right", shadow = True, prop={'size': 20})

w = 0.76
plt.subplot(322)
plt.title("Espacio Fase (1er condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 25)
plt.xlabel("Ángulo", fontsize = 25)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "green", label = "$\mu$=0 , $\omega$=0.76")
plt.tick_params(labelsize=20)
plt.legend(loc = "upper right", shadow = True, prop={'size': 20})

mu = 2.0
w = 0.39
plt.subplot(323)
plt.title("Espacio Fase (2da condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 25)
plt.xlabel("Ángulo", fontsize = 25)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "purple", label = "$\mu$=2.0 , $\omega$=0.39")
plt.tick_params(labelsize=20)
plt.legend(loc = "upper right", shadow = True, prop={'size': 20})

w = 0.76
plt.subplot(324)
plt.title("Espacio Fase (2da condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 25)
plt.xlabel("Ángulo", fontsize = 25)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "purple", label = "$\mu$=2.0 , $\omega$=0.76")
plt.tick_params(labelsize=20)
plt.legend(loc = "upper right", shadow = True, prop={'size': 20})


mu = 0.1
w = 0.39
plt.subplot(325)
plt.title("Espacio Fase (3ra condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 25)
plt.xlabel("Ángulo", fontsize = 25)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "blue", label = "$\mu$=0.1 , $\omega$=0.39")
plt.tick_params(labelsize=20)
plt.legend(loc = "upper right", shadow = True, prop={'size': 20})

w = 0.76
plt.subplot(326)
plt.title("Espacio Fase (3ra condicion inicial)", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 25)
plt.xlabel("Ángulo", fontsize = 25)
plt.grid(True)
plt.plot(gena(t), genv(t), color = "blue", label = "$\mu$=0.1 , $\omega$=0.76")
plt.tick_params(labelsize=20)
plt.legend(loc = "upper right", shadow = True, prop={'size': 20})

plt.show()

# %% [markdown]
# ### **Utiliza el modulo de odeint en la libreria scipy (from scipy.integrate import odeint) para encontrar soluciones numéricas en los siguientes problemas.**

# %% [markdown]
# ## **2.- Ecuación no lineal no forzada sin amortiguamiento.**

# %% [markdown]
# <font color=blue>
#
# Tenemos ahora la ecuación no lineal, antes de poner la ecuación no forzada y sin amortiguaminto, se pondrá la ecuación no lineal completa y se irán desglosando los casos de cada inciso.
# <br>
#     $$\boxed{\ddot{\theta} + \mu\dot{\theta} + \omega_0^2\sin(\theta) = A\cos(wt - \delta)}$$
# <br>
#
# Para este caso tenemos una ecuación no lineal, no forzada y sin amortiguamiento, quiere decir que $\mu=0$ y el término $A\cos(\omega t)$ no contribuyen, quedando la ecuación diferencial de la siguiente manera:
#
# $$\boxed{\ddot{\theta} + \omega_0^2\sin{\theta}=0}$$
#
# </font>

# %% [markdown]
# **a) Para un ángulo inicial de 70 grados en reposo y una frecuencia natural unitaria, realiza una gráfica donde compares la solucion numérica del ángulo y su velocidad con aquella de la ecuación lineal usando las mismas condiciones iniciales.**

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt
from scipy.integrate import odeint


def nolin(y,t):
    theta, omega = y
    dydt = [omega, -np.sin(theta)]
    return dydt

def lin(y,t):
    theta, omega = y
    dydt = [omega, -theta]
    return dydt

y0 = [70*np.pi/180,0]
t = np.linspace(0,20,1000)

plt.figure(figsize=(15,10))

plt.subplot(2,1,1)
solnl = odeint(nolin ,y0 ,t)
plt.title("Gráfica de ecuación no lineal", fontsize = 15)
plt.plot(t, solnl[:,0], color = "orange", label='$ \Theta $(t)')
plt.plot(t, solnl[:,1], color = "red", label='$\omega$(t)')
plt.xlabel("tiempo")
plt.grid()
plt.legend(loc = "upper right", shadow = True)

plt.subplot(2,1,2)
soll = odeint(lin ,y0 ,t)
plt.title("Gráfica de ecuacón lineal", fontsize = 15)
plt.plot(t, soll[:,0], color = "orange", label='$\Theta$(t)')
plt.plot(t, soll[:,1], color = "red", label='$\omega$(t)')
plt.xlabel("tiempo")
plt.grid()
plt.legend(loc = "upper right", shadow = True)

plt.show()

# %% [markdown]
# **b) Construye el espacio fase para una frecuencia natural unitaria, usando trayectorias que partan del reposo con un ángulo inicial que vaya de -90 a 90 grados, en intervalos de 10 grados. Suma dos trayectorias que den vueltas, una encontra de las manecillas del reloj y otra a favor.**

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt
from scipy.integrate import odeint


def nolin(y,t):
    theta, omega = y
    dydt = [omega, -np.sin(theta)]
    return dydt


t = np.linspace(0,20,1000)

plt.figure(figsize=(15,10))
plt.title("Espacio fase de intervalo [-90,90] grados", fontsize = 15)
y0 = [90*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "orange", label = '$\Theta_0$=[-90,90]')
plt.legend()

y0 = [80*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "red", label = '$\Theta_0$[-80,80]')
plt.legend()

y0 = [70*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "violet", label = '$\Theta_0$[-70,70]')
plt.legend()

y0 = [60*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "blue", label = '$\Theta_0$[-60,60]')
plt.legend()

y0 = [50*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "green", label = '$\Theta_0$[-50,50]')
plt.legend()

y0 = [40*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "pink", label = '$\Theta_0$[-40,40]')
plt.legend()

y0 = [30*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "black",label = '$\Theta_0$[-30,30]')
plt.legend()

y0 = [20*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "magenta", label = '$\Theta_0$[-20,20]')
plt.legend()

y0 = [10*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "cyan", label = '$\Theta_0$[-10,10]')
plt.legend()

y0 = [0*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "yellow", label = '$\Theta_0$=0')
plt.legend()

y0 = [-10*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "cyan")

y0 = [-20*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "magenta")

y0 = [-30*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "black")

y0 = [-40*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "pink")

y0 = [-50*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "green")

y0 = [-60*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "blue")

y0 = [-70*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "violet")

y0 = [-80*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "red")

y0 = [-90*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "orange")

plt.xlabel("Ángulo", fontsize = 20)
plt.ylabel("Velocidad", fontsize = 20)
plt.tick_params(labelsize=20)
plt.grid()


plt.show()

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt
from scipy.integrate import odeint


def nolin(y,t):
    theta, omega = y
    dydt = [omega, -np.sin(theta)]
    return dydt


t = np.linspace(0,20,1000)



plt.figure(1,figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)

plt.subplot(121)
plt.title("Sentido horario")
y0 = [50*np.pi/180,0]
soll1 = odeint(nolin ,y0 ,t)
plt.plot(soll1[:,0], soll1[:,1], color = "orange",label= '$\Theta$=50')
plt.xlabel("Angulo", fontsize = 15)
plt.ylabel("Velocidad", fontsize = 15)
plt.grid()
plt.legend()

y0 = [-50*np.pi/180,0]
soll2 = odeint(nolin ,y0 ,t)
plt.subplot(122)
plt.title("Sentido Antihorario")
plt.plot(soll2[:,0], soll2[:,1], color = "red",label= '$\Theta$=-50')
plt.xlabel("Ángulo", fontsize = 15)
plt.ylabel("Velocidad", fontsize = 15)
plt.grid()
plt.legend()
plt.show()

plt.figure(figsize=(8,8))
plt.title("Resultado de la suma de dos trayectorias")
plt.plot(soll1[:,0] + soll2[:,0], soll1[:,1] + soll2[:,1], color = "orange")
plt.xlabel("Ángulo", fontsize = 15)
plt.ylabel("Velocidad", fontsize = 15)
plt.grid()
plt.show()

# %% [markdown]
# <font color=blue>
#
# En el esapcio fase no se puede notar nada, esto se debe a que la suma de dos trayectorias idénticas pero con sentido opuesto suman cero en todos sus puntos, de hecho la gráfica debería mostrar solamente un punto en la coordenada (0,0)
# <br>
#
# </font>

# %% [markdown]
# ## **3.- Ecuación no lineal amortiguada no forzada.**

# %% [markdown]
# <font color=blue>
#
# Tenemos ahora la ecuación no lineal, amortiguada y no forzada:
# <br>
#     $$\boxed{\ddot{\theta} + \mu\dot{\theta} + \omega_0^2\sin(\theta) = 0}$$
# <br>
#
# </font>

# %% [markdown]
# **a) Utiliza un parametro de amortiguamiento de 0.02, la frecuencia natural unitaria y observa cómo el espacio fase se distorciona. Compara cada trayectoria del inciso b) del ejercio anterior con este caso amortiguado.**

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt
from scipy.integrate import odeint


def nolin(y,t):
    theta, omega = y
    dydt = [omega, -0.02*omega -w*np.sin(theta)]
    return dydt

w=1
t = np.linspace(0,1000,100000)

plt.figure(figsize=(8,8))
plt.title("Espacio Fase", fontsize = 15)
y0 = [70*np.pi/180,0]
sol = odeint(nolin ,y0 ,t)
plt.plot(sol[:,0], sol[:,1], color = "orange", label = '$\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

# %% [markdown]
# <font color=blue>
#
# Dado que el coeficiente de fricción es demasiado bajo se puede observar como el sistema pierde energía, la velocidad decrementa y análogamente la amplitud, hasta un punto en el que llegue a 0.
#
#
# </font>

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt
from scipy.integrate import odeint


def nolin(y,t):
    theta, omega = y
    dydt = [omega, -np.sin(theta)]
    return dydt

def nolin2(y,t):
    theta, omega = y
    dydt = [omega, -0.02*omega -w*np.sin(theta)]
    return dydt
w=1
t = np.linspace(0,20,1000)

plt.figure(figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
y0 = [90*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "orange", label = '$\Theta_0$=[-90,90]')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(1,2,2)
y0 = [90*np.pi/180,0]
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "orange", label = '$\Theta_0$=[-90,90], $\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
y0 = [80*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "red", label = '$\Theta_0$[-80,80]')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(1,2,2)
y0 = [80*np.pi/180,0]
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "red", label = '$\Theta_0$=[-80,80], $\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
y0 = [70*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "violet", label = '$\Theta_0$[-70,70]')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(1,2,2)
y0 = [70*np.pi/180,0]
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "violet", label = '$\Theta_0$=[-70,70], $\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
y0 = [60*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "blue", label = '$\Theta_0$[-60,60]')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(1,2,2)
y0 = [60*np.pi/180,0]
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "blue", label = '$\Theta_0$=[-60,60], $\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
y0 = [50*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "green", label = '$\Theta_0$[-50,50]')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(1,2,2)
y0 = [50*np.pi/180,0]
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "green", label = '$\Theta_0$=[-50,50], $\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
y0 = [40*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "pink", label = '$\Theta_0$[-40,40]')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(1,2,2)
y0 = [40*np.pi/180,0]
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "pink", label = '$\Theta_0$=[-40,40],  $\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
y0 = [30*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "black",label = '$\Theta_0$[-30,30]')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(1,2,2)
y0 = [30*np.pi/180,0]
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "black", label = '$\Theta_0$=[-30,30],  $\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
y0 = [20*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "magenta", label = '$\Theta_0$[-20,20]')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(1,2,2)
y0 = [20*np.pi/180,0]
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "magenta", label = '$\Theta_0$=[-20,20],  $\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
plt.subplots_adjust(top=0.92, bottom=0.1, left=0.125, right=0.9, hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
y0 = [10*np.pi/180,0]
soll = odeint(nolin ,y0 ,t)
plt.plot(soll[:,0], soll[:,1], color = "cyan", label = '$\Theta_0$[-10,10]')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(1,2,2)
y0 = [10*np.pi/180,0]
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "cyan", label = '$\Theta_0$=[-10,10], $\mu$=0.02')
plt.legend()
plt.xlabel("Ángulo")
plt.ylabel("Velocidad")
plt.grid()
plt.show()

# %% [markdown]
# ## 4.- Ecuación no lineal completa.

# %% [markdown]
# <font color=blue>
#
# Para este caso tenemos la ecuación no lineal completa:
# <br>
#     $$\boxed{\ddot{\theta} + \mu\dot{\theta} + \omega_0^2\sin(\theta) = A\cos(wt - \delta)}$$
# <br>
#
#
# </font>

# %% [markdown]
# **a) Usando $\mu = 3\pi/2$,  $\omega = 2\pi$,  $\omega_0= 3\pi$ , grafica la solución para cinco casos de A alrededor de 1.05. Qué pasa con las soluciones. ¿Qué ocurre si A=2?**
#
# **b) Obten las trayectorias en el espacio fase de los casos del inciso anterior.**

# %%
# %matplotlib inline

import numpy as np                                       #Importamos numpy como plot
import matplotlib.pyplot as plt                          #Importamos matplotlib como plt
from scipy.integrate import odeint


def nolin(y,t):
    theta, omega = y
    dydt = [omega, -(3*np.pi/2)*omega -((3*np.pi)**2)*np.sin(theta) + 1.05*np.cos(2*np.pi*t- np.arctan(3/5))]
    return dydt

def nolin2(y,t):
    theta, omega = y
    dydt = [omega, -(3*np.pi/2)*omega -((3*np.pi)**2)*np.sin(theta) + 1.58*np.cos(2*np.pi*t - np.arctan(3/5))]
    return dydt

def nolin3(y,t):
    theta, omega = y
    dydt = [omega, -(3*np.pi/2)*omega -((3*np.pi)**2)*np.sin(theta) + 0.65*np.cos(2*np.pi*t - np.arctan(3/5))]
    return dydt

def nolin4(y,t):
    theta, omega = y
    dydt = [omega, -(3*np.pi/2)*omega -((3*np.pi)**2)*np.sin(theta) + 1.37*np.cos(2*np.pi*t - np.arctan(3/5))]
    return dydt

def nolin5(y,t):
    theta, omega = y
    dydt = [omega, -(3*np.pi/2)*omega -((3*np.pi)**2)*np.sin(theta) + 1.95*np.cos(2*np.pi*t - np.arctan(3/5))]
    return dydt

def nolin6(y,t):
    theta, omega = y
    dydt = [omega, -(3*np.pi/2)*omega -((3*np.pi)**2)*np.sin(theta) + 2*np.cos(2*np.pi*t - np.arctan(3/5))]
    return dydt

t = np.linspace(0,20,100000)

plt.figure(figsize=(30,30))

y0 = [0,0]

plt.subplot(621)
sol = odeint(nolin ,y0 ,t)
plt.plot(sol[:,0], sol[:,1], color = "orange")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(622)
sol = odeint(nolin ,y0 ,t)
plt.plot(t, sol[:,0], color = "orange")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(623)
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(sol2[:,0], sol2[:,1], color = "red")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(624)
sol2 = odeint(nolin2 ,y0 ,t)
plt.plot(t,sol2[:,0], color = "red")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(625)
sol3 = odeint(nolin3 ,y0 ,t)
plt.plot(sol3[:,0], sol3[:,1], color = "blue")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(626)
sol3 = odeint(nolin3 ,y0 ,t)
plt.plot(t,sol3[:,0], color = "blue")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(627)
sol4 = odeint(nolin4 ,y0 ,t)
plt.plot(sol4[:,0], sol4[:,1], color = "cyan")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(628)
sol4 = odeint(nolin4 ,y0 ,t)
plt.plot(t,sol4[:,0], color = "cyan")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(629)
sol5 = odeint(nolin5 ,y0 ,t)
plt.plot(sol5[:,0], sol5[:,1], color = "purple")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(6,2,10)
sol5 = odeint(nolin5 ,y0 ,t)
plt.plot(t,sol5[:,0], color = "purple")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(6,2,11)
sol6 = odeint(nolin6 ,y0 ,t)
plt.plot(sol6[:,0], sol6[:,1], color = "green")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.subplot(6,2,12)
sol6 = odeint(nolin6 ,y0 ,t)
plt.plot(t,sol6[:,0], color = "green")
plt.xlabel("Angulo")
plt.ylabel("Velocidad")
plt.grid()

plt.show()

# %% [markdown]
# <font color=blue>
#
# a) Todas las soluciones tienen el mismo comportamiento, la condición de amplitud elegida solamente afecta al inicio de la solución, y posteriormente todas tienen el mismo comportamiento.
#
# </font>

# %% [markdown]
# ## **BONUS: Ve si puedes obtener un diagrama de bifurcación para esta ecuación no lineal. Busca información en la red para ver cómo hacerlo.**

# %% [markdown]
# <font color=blue>
#
# Los diagramas de bifurcación son utilizados para estudiar un parámetro en una ecuación diferencial basándose en los puntos de equilibrio, es decir cuando la derivada es cero. En nuestro caso tenemos la siguiente ecuación diferncial:
#
# <br>
#     $$\boxed{\ddot{\theta} + \mu\dot{\theta} + \omega_0^2\sin(\theta) = A\cos(wt - \delta)}$$
# <br>
# Teniendo $\mu$=$\frac{3\pi}{2}$, $\omega$=$2\pi$, $\omega_0$=$9\pi^2$
# <br>
#
# Con un cambio de variable $\dot\omega$=$\theta$
#
# Obtenemos
# <br>
#     $$\boxed{\frac{d\omega}{dt}=-\frac{3\pi}{2}\omega - 9\pi^2\sin(\theta) + A\cos(2\pi t - \frac{3}{5})}$$
# <br>
#
# El parámetro que nos interesa variar es la amplitud A. Generamos el campo direccional de la ecuación diferencial.
# </font>

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import integrate
 
# Differential equation
# diff = y'= y/x (or say x+y)
def diff(x,y):
    return y/x # try also x+y

x = np.linspace(-5,5,30)
y = np.linspace(-5,5,30)

# use x,y
for j in x:
    for k in y:
        slope = diff(j,k)
        domain = np.linspace(j-0.07,j+0.07,2)
        def fun(x1,y1):
            z = slope*(domain-x1)+y1
            return z
        plt.plot(domain,fun(j,k),solid_capstyle='projecting',solid_joinstyle='bevel')

plt.title("Slope field y'")
plt.grid(True)
plt.show()
    
print("End of the program")
# Out:
# End of the program
